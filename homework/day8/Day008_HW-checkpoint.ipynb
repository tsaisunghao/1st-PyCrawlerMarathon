# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
url_dcard = 'https://www.dcard.tw/f'
headers = {'user-agent': 'my-app/0.0.1'}
'''
Your Code Here
'''
res_dcard=requests.get(url_dcard,headers=headers)

#r.encoding = 'utf-8'
#print(r.text[0:3000])

# %%
res_dcard
# Out:
# <Response [200]>

# %%
res_dcard.text
# Out:
# '<!DOCTYPE html><html lang="zh-Hant-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><title data-react-helmet="true">Dcard</title><meta data-react-helmet="true" property="og:image" content="https://www.dcard.tw/build/landing-c9e7b8fb.png"/><meta data-react-helmet="true" property="og:image:secure_url" content="https://www.dcard.tw/build/landing-c9e7b8fb.png"/><meta data-react-helmet="true" charSet="utf-8"/><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" name="application-name" content="Dcard"/><meta data-react-helmet="true" name="apple-itunes-app" content="app-id=951353454"/><meta data-react-helmet="true" name="theme-color" content="#006aa6"/><meta data-react-helmet="true" name="mobile-web-app-capable" content="yes"/><meta data-react-helmet="true" name="apple-mobile-web-app-capable" content="yes"/><meta data-react-helmet="true" property="fb:app_id" content="211628828926493"/><meta 
# ...

# %%
res_dcard.encoding='utf-8'

# %%
soup_dcard = BeautifulSoup(res_dcard.text,'html5lib')

# %%
soup_dcard
# Out:
# <!DOCTYPE html>
# ...

# %%
h3_tags = soup_dcard.select('h3')
for t in h3_tags:
    print(t.text)
# Out:
# #更新！文長～終於告白了！
# 謝和弦，你的家教真棒
# 在客廳愛愛被老母發現（微西斯）
# 「愛」與「被愛」的差別，你知道嗎？
# 社團咖熱血物語——✨社團爆爆✨，快來加入成為那個咖😎
# 是EXO變了 還是只是我不了解他們
# 謝和弦是在哈囉？？
# 台鐵攻擊
# 消費前隊友和標題殺人已經不流行了不好意思！
# 蔡桃貴限動..？
# #黑特新光三越nars櫃哥他說沒錢就給我滾蛋
# 刺青分享「我們」的故事
# (更 Red Velvet全員開通IG🎉
# 文長）別買淘寶、謹慎買衣
# 謝和弦真的很脫序
# 瞬間浪費五隻唇膏/護唇膏😱😱😱
# 《因為脫褲子得到男友》-男友篇
# 謝和弦事件
# 最後一次見 高以翔Godfrey
# 包餡小湯圓 超讚
# 抽100位CITY CAFE！ 透過定期定額投資ETF，有機會累積大財富！（新開戶立即送7-11商品卡200元↗）
# （文長圖多）以為只花了50元就買到設計版權
# 燒了100W支好香才遇得到ㄉ人
# 好想好想好想交男朋友
# CL真的很大方
# #第一張有恐怖圖 你笑起來好可愛
# 所以這人情到底該怎麼還？
# 打開便當盒的那刻，我哭了
# 🔥FreshO2Xweareatiff聯名超美奶茶色☕️
# 就這樣走了...孝子上班途中車禍亡 父悲痛掛看板找真相
# #問 我男友偷偷訂仿品口紅當禮物怎麼辦？
# 喜歡一個人是什麼感覺

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>')
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>

# %%
print(type(res_dcard))
print(type(soup_dcard))
# Out:
# <class 'requests.models.Response'>
# <class 'bs4.BeautifulSoup'>

# %%
# Out:
# str

# %%
# Out:
# <!DOCTYPE html><html lang="zh-Hant-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><title data-react-helmet="true">Dcard</title><meta data-react-helmet="true" property="og:image" content="https://www.dcard.tw/build/landing-c9e7b8fb.png"/><meta data-react-helmet="true" property="og:image:secure_url" content="https://www.dcard.tw/build/landing-c9e7b8fb.png"/><meta data-react-helmet="true" charSet="utf-8"/><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" name="application-name" content="Dcard"

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')

'''
Your Code Here
'''
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# '\nYour Code Here\n'

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url_zhihu = 'https://www.zhihu.com/explore'
r = requests.get(url_zhihu,headers=headers)
r.encoding = 'utf-8'

print(r.text)
# Out:
# <!doctype html>
# ...

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'

'''
Your Code Here
'''
r = requests.get(url,headers=headers)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的

# %%
soup_zhihu=BeautifulSoup(r.text)

# %%
soup_zhihu
# Out:
# <!DOCTYPE html>
# ...

# %%
#root > div > div.App_main_38MbtT > div > div > main > div > div > div:nth-child(2) > a

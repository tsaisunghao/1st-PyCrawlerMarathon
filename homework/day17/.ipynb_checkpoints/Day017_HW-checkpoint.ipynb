# %% [markdown]
# # HTTP 動態網頁架構說明
#
#
# * 了解動態網頁的資料爬蟲策略
# * 知道非同步網頁載入機制（Ajax）
# * 學習兩種對應動態網頁爬蟲的的策略

# %% [markdown]
# ## 作業目標
#
# 回答以下問題：
#
# 1. 動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？
# 2. 還記得我們在 ETTODAY 靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來， 試著回答看看原因是什麼？及該如何檢查？

# %% [markdown]
# ### 1. 動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？

# %% [markdown]
# 靜態網頁設計者必須將網頁內容寫好，客戶端對伺服器請求頁面資訊，伺服器按照使用者請求回傳，缺點是網頁內容只能由設計者更新，使用者無法得到即時的數據更新
#
# 動態網頁可以隨著使用者的操作，網頁內容更新所需的資訊，網住流量需求較小

# %% [markdown]
# ### 2. 還記得我們在 ETTODAY 靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來， 試著回答看看原因是什麼？及該如何檢查？

# %% [markdown]
# 初始載入的頁面。會載入100則「取出今天所有的發文」的日期、時間及標題。因為普通使用者不會一次看完所有當天發的所有新聞，所以設計師在設計回傳頁面時，先預設回傳100比新聞。當使用者將頁面繼續往下拉時，可以發現網頁會持續擴充，是因為伺服器偵測到使用者的特定操作，於是將更多標題持續回傳到列表下方。
# 我們可以在瀏覽器，以Chrome為例，在檢查瀏覽器中的Network,All選項裡先進行資料清除，接著將網頁向下捲動會出現一筆新的伺服器為傳資料，裡面就包含了10比的新聞內容。

# %%
from IPython.display import Image
Image(filename='update_page.JPG')

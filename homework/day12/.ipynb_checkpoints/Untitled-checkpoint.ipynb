# %% [markdown]
# Ettoday 網路爬蟲實作練習
# 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url ='https://www.ettoday.net/news/news-list.htm'

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.text[0:500]
# Out:
# '<!doctype html>\r\n<html lang="zh-Hant" prefix="og:http://ogp.me/ns#" xmlns:wb="http://open.weibo.com/wb" itemscope itemtype="http://schema.org/WebSite">\r\n<head>\r\n<meta charset="utf-8">\r\n<!-- ★★★以下非共用★★★ 開始 -->\r\n<meta name="robots" content="noarchive"/>\r\n<title>新聞總覽 | ETtoday新聞雲</title>\r\n<link rel="canonical" href="https://www.ettoday.net/news/news-list-2019-12-21-0.htm"/>\r\n\r\n<!-- 網頁社群分享meta 開始 -->\r\n<meta property="og:url" itemprop="url" content="https://www.ettoday.net/news/news-list-2019-12-21-0'

# %%
soup = BeautifulSoup(resp.text, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html itemscope="" itemtype="http://schema.org/WebSite" lang="zh-Hant" prefix="og:http://ogp.me/ns#" xmlns:wb="http://open.weibo.com/wb">
# <head>
# <meta charset="utf-8"/>
# <!-- ★★★以下非共用★★★ 開始 -->
# <meta content="noarchive" name="robots">
# <title>新聞總覽 | ETtoday新聞雲</title>
# <link href="https://www.ettoday.net/news/news-list-2019-12-21-0.htm" rel="canonical"/>
# <!-- 網頁社群分享meta 開始 -->
# <meta content="https://www.ettoday.net/news/news-list-2019-12-21-0.htm" itemprop="url" property="og:url"/>
# <meta content="新聞總覽 | ETtoday新聞雲" itemprop="name" property="og:title"/>
# <meta content="https://cdn2.ettoday.net/style/ettoday2017/images/push.jpg" itemprop="image" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="628" property="og:image:height"/>
# <meta content="article" property="og:type"/>
# <meta content="ETtoday.net線上提供即時新聞，包括政治、財經、社會及國際要聞，以及生活、消費、寵物、新奇、娛樂、運動、旅遊資訊和相關新聞報導。" name="description"/>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
div_tags = soup.find_all("div", class_="part_list_2")

# %%
div_tag=soup.find("div", class_="part_list_2")

# %%
div_tag.find()
# Out:
# <div class="part_list_2">
# <h3><span class="date">2019/12/21 09:43</span><em class="tag c_news">政治</em><a href="/news/20191221/1607063.htm" target="_blank">籲韓粉一起當「糾察隊」　孫大千：落實「愛與包容」</a></h3>
# <h3><span class="date">2019/12/21 09:41</span><em class="tag c_news">政治</em><a href="/news/20191221/1607073.htm" target="_blank">「罷韓遊行」彩蛋曝光！　終點鏡球試燈「雷射光束四射」：榮光照耀我高雄</a></h3>
# <h3><span class="date">2019/12/21 09:41</span><em class="tag c_finance">財經</em><a href="/news/20191221/1607065.htm" target="_blank">台商根留台灣再添一樁　美喆擬建台南新廠後年投產</a></h3>
# <h3><span class="date">2019/12/21 09:31</span><em class="tag c_health">健康</em><a href="/news/20191221/1604251.htm" target="_blank">用錯恐宮縮、關節錯位！電動按摩槍「NG操作」4下場更傷身</a></h3>
# <h3><span class="date">2019/12/21 09:30</span><em class="tag c_fashion">時尚</em><a href="/news/20191221/1603875.htm" target="_blank">史上最夢幻球鞋！KD12 粉紅羽翼、珍珠包圍　網虧：會被女友搶穿</a></h3>
# ...

# %%
div_tag.findChild('h3').findChild('span',class_='date').text
# Out:
# '2019/12/21 09:43'

# %%
div_tag.findChild('h3').findChild('em',class_='tag c_news').text
# Out:
# '政治'

# %%
for tagg in div_tag:
    print(tagg.findChild('h3').findChild('span',class_='date').text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-653f48084b46> in <module>()
#       1 for tagg in div_tag:
# ----> 2     print(tagg.findChild('h3').findChild('span',class_='date').text)
#
# C:\Users\Vincent\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     735             raise AttributeError(
#     736                 "'%s' object has no attribute '%s'" % (
# --> 737                     self.__class__.__name__, attr))
#     738
#     739     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'findChild'

# %%
lv1=div_tag.findChild('h3')

# %%
type(lv1)
# Out:
# bs4.element.Tag

# %%
type(div_tag)
# Out:
# bs4.element.Tag

# %%
lv1()
# Out:
# [<span class="date">2019/12/21 09:43</span>,
#  <em class="tag c_news">政治</em>,
#  <a href="/news/20191221/1607063.htm" target="_blank">籲韓粉一起當「糾察隊」　孫大千：落實「愛與包容」</a>]

# %%
type(div_tags)
# Out:
# bs4.element.ResultSet

# %%
div_tag('span', class_="date")
# Out:
# [<span class="date">2019/12/21 09:43</span>,
#  <span class="date">2019/12/21 09:41</span>,
#  <span class="date">2019/12/21 09:41</span>,
#  <span class="date">2019/12/21 09:31</span>,
#  <span class="date">2019/12/21 09:30</span>,
#  <span class="date">2019/12/21 09:27</span>,
#  <span class="date">2019/12/21 09:23</span>,
#  <span class="date">2019/12/21 09:20</span>,
#  <span class="date">2019/12/21 09:11</span>,
#  <span class="date">2019/12/21 09:10</span>,
#  <span class="date">2019/12/21 09:06</span>,
#  <span class="date">2019/12/21 09:05</span>,
#  <span class="date">2019/12/21 09:04</span>,
#  <span class="date">2019/12/21 09:01</span>,
#  <span class="date">2019/12/21 09:00</span>,
#  <span class="date">2019/12/21 09:00</span>,
#  <span class="date">2019/12/21 09:00</span>,
#  <span class="date">2019/12/21 09:00</span>,
#  <span class="date">2019/12/21 09:00</span>,
#  <span class="date">2019/12/21 08:57</span>,
#  <span class="date">2019/12/21 08:50</span>,
# ...

# %%
time_stmp=[]
catagory=[]
title=[]
for tag in div_tags:
    time_stmp=(tag.find_all('span',class_="date"))
    catagory=(tag.find_all('em'))
    title=(tag.find_all('a'))

# %%
catagory[0:10]
# Out:
# [<em class="tag c_news">政治</em>,
#  <em class="tag c_news">政治</em>,
#  <em class="tag c_finance">財經</em>,
#  <em class="tag c_health">健康</em>,
#  <em class="tag c_fashion">時尚</em>,
#  <em class="tag c_health">健康</em>,
#  <em class="tag c_global">國際</em>,
#  <em class="tag c_news">政治</em>,
#  <em class="tag c_speed">ET車雲</em>,
#  <em class="tag c_consuming">消費</em>]

# %%
time_stmp[0:10]
# Out:
# [<span class="date">2019/12/21 09:43</span>,
#  <span class="date">2019/12/21 09:41</span>,
#  <span class="date">2019/12/21 09:41</span>,
#  <span class="date">2019/12/21 09:31</span>,
#  <span class="date">2019/12/21 09:30</span>,
#  <span class="date">2019/12/21 09:27</span>,
#  <span class="date">2019/12/21 09:23</span>,
#  <span class="date">2019/12/21 09:20</span>,
#  <span class="date">2019/12/21 09:11</span>,
#  <span class="date">2019/12/21 09:10</span>]

# %%
pattern=r''
